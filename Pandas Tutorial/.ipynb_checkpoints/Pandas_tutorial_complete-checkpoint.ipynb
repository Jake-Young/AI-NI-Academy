# %% [markdown]
# # Python Pandas Tutorial
# ###### by Eóin McMahon
# ***
#
# ![panda](pandaatcomputer.jpg)
# ***
# ##### Pandas is very important for reading in your data and viewing it in an informative way, It will help a lot when you need to do any sort of data analysing. In this tutorial I will go over the basics of python pandas so that you will be able to read and manipulate data that you can use later for anything you see fit.

# %% [markdown]
# ### First, your imports
# ***
# I will also be using matplotlib in this tutorial to help visualise the data graphically. I am using "pd" as an alias for pandas to save me the time of typing it out

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Read in your Data
# ***

# %% [markdown]
# read in your data using `pd.read_csv(filename)` and store it in a variable named `dataframe`.You can use `dataframe.head()` to show the the first rows of data in a neat table. `dataframe.head()` by default produces the first 5 rows however you can specify how many rows you want to see by using the integer as a parameter in the `dataframe.head()` function you can also use the `dataframe.tail()` function to select from the end of the dataframe

# %%
dataframe = pd.read_csv("titanic_dataset.csv")

# %% [markdown]
# print the head of the dataframe

# %%
dataframe.head()

# %% [markdown]
# print the tail of the dataframe

# %%
dataframe.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1305     3.0       0.0      Zabour, Miss. Thamine  female   NaN    1.0    0.0
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer    male  26.5    0.0    0.0
# 1307     3.0       0.0        Zakarian, Mr. Ortin    male  27.0    0.0    0.0
# 1308     3.0       0.0         Zimmerman, Mr. Leo    male  29.0    0.0    0.0
# 1309     NaN       NaN                        NaN     NaN   NaN    NaN    NaN
#
#       ticket     fare cabin embarked boat   body home.dest
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN
# 1309     NaN      NaN   NaN      NaN  NaN    NaN       NaN

# %% [markdown]
# we can use `dataframe.describe()` to give a quick summary of our data. print description table of dataframe

# %%
dataframe.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# #### Selecting  Rows and Columns
# ***

# %% [markdown]
# select specific columns by using `dataframe[column name]`, this yields a series. print the age series of the dataframe column

# %%
dataframe["age"] [0:10]
# Out:
# 0    29.0000
# 1     0.9167
# 2     2.0000
# 3    30.0000
# 4    25.0000
# 5    48.0000
# 6    63.0000
# 7    39.0000
# 8    53.0000
# 9    71.0000
# Name: age, dtype: float64

# %% [markdown]
# we can view the series as a list using the `.tolist()` function on the dataframe column. print out the age column of the dataframe as a list.

# %%
dataframe["age"].tolist()[0:10]
# Out:
# [29.0, 0.9167, 2.0, 30.0, 25.0, 48.0, 63.0, 39.0, 53.0, 71.0]

# %% [markdown]
# select multiple columns by using `dataframe[[column1, column2]]`

# %%
dataframe[["age", "pclass"]][0:10]
# Out:
#        age  pclass
# 0  29.0000     1.0
# 1   0.9167     1.0
# 2   2.0000     1.0
# 3  30.0000     1.0
# 4  25.0000     1.0
# 5  48.0000     1.0
# 6  63.0000     1.0
# 7  39.0000     1.0
# 8  53.0000     1.0
# 9  71.0000     1.0

# %% [markdown]
# #### Getting rows with splicing
# ***
# Select the first 3 Rows using python splicing [from:to]

# %%
dataframe[:3]
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0     1.0       1.0   Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1     1.0       1.0  Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2     1.0       0.0    Allison, Miss. Helen Loraine  female   2.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0    0.0   24160  211.3375       B5        S    2   NaN
# 1    2.0  113781  151.5500  C22 C26        S   11   NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %% [markdown]
# select from the 3rd row to the 6th row. Remember! python splicing is [inclusive: exclusive]

# %%
dataframe[3:7]
# Out:
#    pclass  survived                                             name     sex  \
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5     1.0       1.0                              Anderson, Mr. Harry    male
# 6     1.0       1.0                Andrews, Miss. Kornelia Theodosia  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 3  30.0    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0    0.0    0.0   19952   26.5500      E12        S    3    NaN
# 6  63.0    1.0    0.0   13502   77.9583       D7        S   10    NaN
#
#                          home.dest
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY

# %% [markdown]
# #### Selction by Label
# ***

# %% [markdown]
# use `dataframe.loc(dataframe[columnname] == value)` to access a group of rows and columns by label(s) or a boolean array. In this case, create a new dataframe holding only the passengers who are twenty nine years old.

# %%
# select rows where passenger age is 29
twenty_nine_year_old = dataframe.loc[dataframe["age"] == 29.0]
twenty_nine_year_old.head()
# Out:
#      pclass  survived                                             name  \
# 0       1.0       1.0                    Allen, Miss. Elisabeth Walton
# 24      1.0       1.0                                Bird, Miss. Ellen
# 189     1.0       0.0                           Long, Mr. Milton Clyde
# 226     1.0       0.0                        Pears, Mr. Thomas Clinton
# 369     2.0       0.0  Chapman, Mrs. John Henry (Sara Elizabeth Lawry)
#
#         sex   age  sibsp  parch       ticket      fare cabin embarked boat  \
# 0    female  29.0    0.0    0.0        24160  211.3375    B5        S    2
# 24   female  29.0    0.0    0.0     PC 17483  221.7792   C97        S    8
# 189    male  29.0    0.0    0.0       113501   30.0000    D6        S  NaN
# 226    male  29.0    1.0    0.0       113776   66.6000    C2        S  NaN
# 369  female  29.0    1.0    0.0  SC/AH 29037   26.0000   NaN        S  NaN
#
#       body               home.dest
# 0      NaN            St Louis, MO
# ...

# %% [markdown]
# we can select rows where the wanted values are in a list by using the `isin()` function. <br>
# Create a list called teenagers, and select all the rows where the passenger age is within the age range of 13 to 19

# %%
teenagers = [13,14,15,16,17,18,19]
dataframe.loc[dataframe['age'].isin(teenagers)]
# Out:
#       pclass  survived                                               name  \
# 11       1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 27       1.0       1.0            Bishop, Mrs. Dickinson H (Helen Walton)
# 53       1.0       0.0                             Carrau, Mr. Jose Pedro
# 55       1.0       1.0                          Carter, Miss. Lucile Polk
# 92       1.0       1.0          Dick, Mrs. Albert Adrian (Vera Gillespie)
# 114      1.0       0.0                     Fortune, Mr. Charles Alexander
# 137      1.0       1.0                       Graham, Miss. Margaret Edith
# 159      1.0       1.0                       Hippach, Miss. Jean Gertrude
# 187      1.0       1.0                          Lines, Miss. Mary Conover
# 193      1.0       1.0                  Madill, Miss. Georgette Alexandra
# 195      1.0       1.0                              Maioni, Miss. Roberta
# 197      1.0       0.0                          Marvin, Mr. Daniel Warner
# ...

# %% [markdown]
# you can use `dataframe.at(row, column)` to get value at specified row/column pair. use this to get the age of the passenger in the 10th row

# %%
# age of passenger in the tenth row
dataframe.at[10, "age"]
# Out:
# 47.0

# %% [markdown]
# you can use boolean indexing to get all the rows that match a given selection criteria. using `dataframe[dataframe[columnname] criteria]` store all rows of passengers over the age 65 in a new dataframe named "elderly"

# %%
elderly = dataframe[dataframe["age"] > 65]
elderly.head()
# Out:
#      pclass  survived                                               name  \
# 9       1.0       0.0                            Artagaveytia, Mr. Ramon
# 14      1.0       1.0               Barkworth, Mr. Algernon Henry Wilson
# 61      1.0       1.0  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81      1.0       0.0                       Crosby, Capt. Edward Gifford
# 135     1.0       0.0                          Goldschmidt, Mr. George B
#
#         sex   age  sibsp  parch     ticket     fare cabin embarked boat  \
# 9      male  71.0    0.0    0.0   PC 17609  49.5042   NaN        C  NaN
# 14     male  80.0    0.0    0.0      27042  30.0000   A23        S    B
# 61   female  76.0    1.0    0.0      19877  78.8500   C46        S    6
# 81     male  70.0    1.0    1.0  WE/P 5735  71.0000   B22        S  NaN
# 135    male  71.0    0.0    0.0   PC 17754  34.6542    A5        C  NaN
#
#       body                home.dest
# 9     22.0      Montevideo, Uruguay
# ...

# %% [markdown]
# Using a for loop, we can loop through a dataset column to grab its values. loop through all names in the dataframe and print out each name.

# %%
for name in dataframe["name"]:
    print(name)
# Out:
# Allen, Miss. Elisabeth Walton
# Allison, Master. Hudson Trevor
# Allison, Miss. Helen Loraine
# Allison, Mr. Hudson Joshua Creighton
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Anderson, Mr. Harry
# Andrews, Miss. Kornelia Theodosia
# Andrews, Mr. Thomas Jr
# Appleton, Mrs. Edward Dale (Charlotte Lamson)
# Artagaveytia, Mr. Ramon
# Astor, Col. John Jacob
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# Aubart, Mme. Leontine Pauline
# Barber, Miss. Ellen "Nellie"
# Barkworth, Mr. Algernon Henry Wilson
# Baumann, Mr. John D
# Baxter, Mr. Quigg Edmond
# Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# Bazzani, Miss. Albina
# Beattie, Mr. Thomson
# Beckwith, Mr. Richard Leonard
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# Behr, Mr. Karl Howell
# Bidois, Miss. Rosalie
# Bird, Miss. Ellen
# Birnbaum, Mr. Jakob
# Bishop, Mr. Dickinson H
# Bishop, Mrs. Dickinson H (Helen Walton)
# Bissette, Miss. Amelia
# Bjornstrom-Steffansson, Mr. Mauritz Hakan
# ...

# %% [markdown]
# #### Dataframe Visualisation
# ***

# %% [markdown]
# we can visualise specific columns using matplotlib functions `.plot()` or `.hist()` draw a line graph of the fare cost against the amount of people. also, plot a histogram of the passenger age and amount of people.

# %%
dataframe["fare"].plot()
plt.title("line graph of fare cost vs how many people purchased that specific fare")
plt.ylabel("fare price")
plt.xlabel("count")
plt.show()

dataframe['age'].hist()
plt.title("historgram of passenger Age")
plt.ylabel("count")
plt.xlabel("passenger age")
plt.show()

# %% [markdown]
# or we can plot all columns by calling `.plot()` on the whole dataframe. plot a line graph of the whole dataframe

# %%
dataframe.plot(figsize=(10,7.5))

# %% [markdown]
# #### Dataframe Manipulation
# ***

# %% [markdown]
# You can drop columns using `dataframe.drop(columns=[])` to drop off the columns that you dont need. create a new dataframe with only the columns "pclass, survived, name, sex, age, ticket, fare"

# %%
dataframe = dataframe.drop(columns=["body", "home.dest", "sibsp", "parch", "cabin", "boat", "embarked"], axis = 1)
dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  ticket      fare
# 0  29.0000   24160  211.3375
# 1   0.9167  113781  151.5500
# 2   2.0000  113781  151.5500
# 3  30.0000  113781  151.5500
# 4  25.0000  113781  151.5500

# %% [markdown]
# We can rename columns using `dataframe.rename(columns={oldname:newname}, inplace = True)` rename the column "fare" to "ticketPrice"

# %%
dataframe.rename(columns={"fare": "ticketPrice"}, inplace=True)
dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1     False                    allen, miss. elisabeth walton  female
# 1       1      True                   allison, master. hudson trevor    male
# 2       1     False                     allison, miss. helen loraine  female
# 3       1     False             allison, mr. hudson joshua creighton    male
# 4       1     False  allison, mrs. hudson j c (bessie waldo daniels)  female
#
#    age  ticket  ticketPrice
# 0   29   24160     211.3375
# 1    0  113781     151.5500
# 2    2  113781     151.5500
# 3   30  113781     151.5500
# 4   25  113781     151.5500

# %% [markdown]
# We can concatenate separate dataframes into one dataframe
# use `pd.concat([column1, column2], axis = 1)`. create a dataframe for all the ages and a dataframe of all the ticketPrices and concatenate them into one dataframe called ages_and_fares.

# %%
ages = dataframe["age"]
fares = dataframe["ticketPrice"]
ages_and_fares = pd.concat([ages, fare], axis = 1)
ages_and_fares.head()
# Out:
#    age  ticketPrice
# 0   29     211.3375
# 1    0     151.5500
# 2    2     151.5500
# 3   30     151.5500
# 4   25     151.5500

# %% [markdown]
# We can change the values in specific row and column pairs by using the `dataframe.at()` function. set the survived column of the first row to 0.0

# %%
dataframe.at[0,'survived'] = 0.0
#now the dataframe states that passenger in the first row didn't surive
dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       0.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  ticket  ticketPrice
# 0  29.0000   24160     211.3375
# 1   0.9167  113781     151.5500
# 2   2.0000  113781     151.5500
# 3  30.0000  113781     151.5500
# 4  25.0000  113781     151.5500

# %% [markdown]
# we can drop rows where the age is not specfied by using `dataframe[np.isfinite(dataframe[column])]`, np is the alias I created for numpy, this is the only time in this tutorial I have used numpy but it can be used for a lot more than I have shown. See the numpy tutorial for more information on it. use this to drop all NaN values from the age column

# %%
dataframe = dataframe[np.isfinite(dataframe["age"])]
dataframe.head(20)
# Out:
#     pclass  survived                                               name  \
# 0      1.0       0.0                      Allen, Miss. Elisabeth Walton
# 1      1.0       1.0                     Allison, Master. Hudson Trevor
# 2      1.0       0.0                       Allison, Miss. Helen Loraine
# 3      1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4      1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5      1.0       1.0                                Anderson, Mr. Harry
# 6      1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7      1.0       0.0                             Andrews, Mr. Thomas Jr
# 8      1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9      1.0       0.0                            Artagaveytia, Mr. Ramon
# 10     1.0       0.0                             Astor, Col. John Jacob
# 11     1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# Now all `NaN` age values have been removed, however now their indexes are missing. For example index 15 is now missing form the dataframe, reset the indexes using `dataframe.reset_index()`. Also use the `drop=True` parameter to avoid the old indexes being added as a column.

# %%
dataframe = dataframe.reset_index(drop=True)
dataframe.head(20)
# Out:
#     pclass  survived                                               name  \
# 0      1.0       0.0                      Allen, Miss. Elisabeth Walton
# 1      1.0       1.0                     Allison, Master. Hudson Trevor
# 2      1.0       0.0                       Allison, Miss. Helen Loraine
# 3      1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4      1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5      1.0       1.0                                Anderson, Mr. Harry
# 6      1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7      1.0       0.0                             Andrews, Mr. Thomas Jr
# 8      1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9      1.0       0.0                            Artagaveytia, Mr. Ramon
# 10     1.0       0.0                             Astor, Col. John Jacob
# 11     1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# Notice that the pclass and age columns consists only of floats, if we want to change this to integers we can use the lambda function on the columns. Use dataframe[column] = dataframe[column].apply(lambda oldX: newX) to set all age values to integers and all pclass values to integers

# %%
dataframe["age"] = dataframe["age"].apply(lambda x: int(x))
dataframe["pclass"] = dataframe["pclass"].apply(lambda x: int(x))

# %%
dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1       0.0                    Allen, Miss. Elisabeth Walton  female
# 1       1       1.0                   Allison, Master. Hudson Trevor    male
# 2       1       0.0                     Allison, Miss. Helen Loraine  female
# 3       1       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#    age  ticket  ticketPrice
# 0   29   24160     211.3375
# 1    0  113781     151.5500
# 2    2  113781     151.5500
# 3   30  113781     151.5500
# 4   25  113781     151.5500

# %% [markdown]
# Using the same logic, set all characters in the name column to lower case

# %%
dataframe["name"] = dataframe["name"].apply(lambda string: string.lower())
dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1       0.0                    allen, miss. elisabeth walton  female
# 1       1       1.0                   allison, master. hudson trevor    male
# 2       1       0.0                     allison, miss. helen loraine  female
# 3       1       0.0             allison, mr. hudson joshua creighton    male
# 4       1       0.0  allison, mrs. hudson j c (bessie waldo daniels)  female
#
#    age  ticket  ticketPrice
# 0   29   24160     211.3375
# 1    0  113781     151.5500
# 2    2  113781     151.5500
# 3   30  113781     151.5500
# 4   25  113781     151.5500

# %% [markdown]
# Notice that survived is a float value of 1 or 0, if we want to change this to True or False, we can use the asType() function. using the asType() function, set the survived column to type boolean.

# %%
dataframe["survived"] = dataframe["survived"].astype(bool)
dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1     False                    allen, miss. elisabeth walton  female
# 1       1      True                   allison, master. hudson trevor    male
# 2       1     False                     allison, miss. helen loraine  female
# 3       1     False             allison, mr. hudson joshua creighton    male
# 4       1     False  allison, mrs. hudson j c (bessie waldo daniels)  female
#
#    age  ticket  ticketPrice
# 0   29   24160     211.3375
# 1    0  113781     151.5500
# 2    2  113781     151.5500
# 3   30  113781     151.5500
# 4   25  113781     151.5500

# %% [markdown]
# double all ticket prices by multiplying the dataframe column by 2.

# %%
dataframe["ticketPrice"] = dataframe["ticketPrice"] * 2

# %%
dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1     False                    allen, miss. elisabeth walton  female
# 1       1      True                   allison, master. hudson trevor    male
# 2       1     False                     allison, miss. helen loraine  female
# 3       1     False             allison, mr. hudson joshua creighton    male
# 4       1     False  allison, mrs. hudson j c (bessie waldo daniels)  female
#
#    age  ticket  ticketPrice
# 0   29   24160      422.675
# 1    0  113781      303.100
# 2    2  113781      303.100
# 3   30  113781      303.100
# 4   25  113781      303.100

# %% [markdown]
# and set it back to normal by dividing by 2

# %%
dataframe["ticketPrice"] = dataframe["ticketPrice"] / 2
dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1     False                    allen, miss. elisabeth walton  female
# 1       1      True                   allison, master. hudson trevor    male
# 2       1     False                     allison, miss. helen loraine  female
# 3       1     False             allison, mr. hudson joshua creighton    male
# 4       1     False  allison, mrs. hudson j c (bessie waldo daniels)  female
#
#    age  ticket  ticketPrice
# 0   29   24160     211.3375
# 1    0  113781     151.5500
# 2    2  113781     151.5500
# 3   30  113781     151.5500
# 4   25  113781     151.5500

# %% [markdown]
# Once we are finished cleaning up our dataframe we can export it back to a csv by using the `dataframe.to_csv()` function. export the data back to a csv.

# %%
cleaned_data = dataframe.to_csv("cleaned_titanic_dataset.csv")
print("clean data exported")
# Out:
# clean data exported
